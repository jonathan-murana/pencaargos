# %% [markdown]
# PENCA 2008

# %%
from IPython.display import Image
import pandas as pd
from os import walk
# %pylab inline
import re
import matplotlib.pyplot as plt
plt.rc('legend', fontsize='small')
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import display, HTML

from datetime import timedelta
from __future__ import print_function, division
import statsmodels.formula.api as smf
import pylab as pl
pd.set_option('precision', 2)

#import plotly.plotly as py
#import plotly.graph_objs as go
#from plotly.tools import FigureFactory as FF
#import scipy
#from xlrd import open_workbook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dire="files/"

def points(xg1,xg2,rg1,rg2):
  res = 0
  if not math.isnan(xg1) and not math.isnan(rg1) and xg1==rg1:
    res += 1
  if not math.isnan(xg2) and not math.isnan(rg2) and xg2==rg2:
    res += 1
  if not math.isnan(xg1) and not math.isnan(rg1):
    if not math.isnan(xg2) and not math.isnan(rg2):
      if ((xg1-xg2) < 0 and (rg1-rg2)< 0 ):
        res+=3 
      if ((xg1-xg2) > 0 and (rg1-rg2)> 0 ):
        res+=3 
      if ((xg1-xg2) == 0 and (rg1-rg2)== 0 ):
        res+=3
  return res

def seller(x):
  return x.split('_')[0].replace('Penca Argos Rusia 2018', '').replace('-','').replace(' ','')

def name(x):
  return x.split('_')[1].replace('Penca Argos Rusia 2018', '').replace('-','').replace(' ','')

def name2(x):
  return x.split('|')[1]

def speed(viejo,nuevo):
   if ( viejo > nuevo ):
     return '-'
   if ( viejo < nuevo ):
     return '+'
   if ( viejo == nuevo ):
     return '='

def myindex(name,data):
   #print(data.index[data.name2==name])
   
   #return data[data.name2==name].index
   #return data.index[data['BoolCol'] == True].tolist()
   
   return 1
   


def one():
  return 1

def incomplete(xg1,xg2):
  if math.isnan(xg1) and math.isnan(xg2):
    return 2
  if math.isnan(xg1):
    return 1
  if math.isnan(xg2):
    return 1

def incompleteff(label,value):
  if not label and math.isnan(value):
    return 2
  if not label:
    return 1
  if math.isnan(value):
    return 1

def total(points,points2):
    return points + points2

#def fixLabel(label):
#    if xlabel == 'Belgica':
#        return  'Bélgica'
#     if xlabel == 'Poloniq':
#        return  'Polonia'
    
#    return label

def pointsff(idx,xlabel,xvalue,rlabel,rvalue,keyx,keyr):
  #display('xlabel'+xlabel+'rlabel'+rlabel)

  #fixxlabel = fixLabel(xlabel)
  if xlabel not in ['Rusia', 'Egipto', 'Arabia Saudita','Uruguay',\
                    'Portugal','Marruecos','España','Irán',\
                    'Francia','Perú','Australia','Dinamarca',\
                    'Argentina','Islandia','Croacia','Nigeria',\
                    'Brasil','Suiza','Costa Rica','Serbia',\
                    'Alemania','México','Suecia','Corea del Sur',\
                    'Bélgica','Panamá','Túnez','Inglaterra',\
                    'Polonia','Senegal','Colombia','Japón']:
        display(idx + ' '+xlabel)
  res = 0
  if xlabel and rlabel and xlabel == rlabel:
    res += 3
  if keyx==keyr:
    res += points(xg1,xg2,rg1,rg2):
    
    
    
  return res

def buildx(file):
  xls = pd.ExcelFile(dire+file)
  y = pd.read_excel(xls, 'Fase de grupos')
  name=y[y.columns[4]][0]
  mail=y[y.columns[10]][0]
  #print(mail)  
  
  #if not mail.strip():
  #if len(str(mail))<4:
  #  print(name + ' vendido por '+ seller("%s|%s|%s" % (file, name, mail)))  
  #print(y[y.columns[10]][0])
   
  y=y[[y.columns[6],y.columns[7],y.columns[8],y.columns[9],]]
  y.columns = ['t1','g1','g2','t2']
  y['id']="%s|%s|%s" % (file, name, mail)
  y['name']=name
  #select rows
  A=y.iloc[4:10]
  B=y.iloc[14:20]
  C=y.iloc[24:30]
  D=y.iloc[34:40]
  E=y.iloc[44:50]
  F=y.iloc[54:60]
  G=y.iloc[64:70]
  H=y.iloc[74:80]
 
  #ff = pd.read_excel(xls, 'Fase final')
  #oct_etq=ff.iloc[4:10]
  
 
  z = pd.concat([A,B,C,D,E,F,G,H],axis=0)
  


  return pd.DataFrame(z)

def buildff(file):
  xls = pd.ExcelFile(dire+file)

  y = pd.read_excel(xls, 'Fase de grupos')
  name=y[y.columns[4]][0]
  mail=y[y.columns[10]][0]
  y = pd.read_excel(xls, 'Fase final')
  
  #name=y[y.columns[4]][0]
  #mail=y[y.columns[4]][0]
  y=y[[y.columns[3],y.columns[4],]]
  y.columns = ['label','value']
  oct1=y.iloc[4:6].copy()
  oct2=y.iloc[7:9].copy()
  oct3=y.iloc[11:13].copy() 
  oct4=y.iloc[14:16].copy() 
  oct5=y.iloc[18:20].copy()
  oct6=y.iloc[21:23].copy()
  oct7=y.iloc[25:27].copy() 
  oct8=y.iloc[28:30].copy() 
  
  #display(oct1['label'])

  oct1['key1']= oct1['label'][4] + '-' + oct1['label'][5]
  oct2['key1']= oct2['label'][7] + '-' + oct2['label'][8]
  oct3['key1']= oct3['label'][11] + '-' + oct3['label'][12]
  oct4['key1']= oct4['label'][14] + '-' + oct4['label'][15]
  oct5['key1']= oct5['label'][18] + '-' + oct5['label'][19]
  oct6['key1']= oct6['label'][21] + '-' + oct6['label'][22]
  oct7['key1']= oct7['label'][25] + '-' + oct7['label'][26]
  oct8['key1']= oct8['label'][28] + '-' + oct8['label'][29]
  

  #z = pd.concat([A,B,C,D,E,F,G,H],axis=0)
  z = pd.concat([oct1,oct2,oct3,oct4,oct5,oct6,oct7,oct8],axis=0)
  
  #z['key']= 'hola' 
    
    
  z['id']="%s|%s|%s" % (file, name, mail)
  return pd.DataFrame(z)  


    
r=buildx("RESULTADO_RESULTADO.xlsx")
rff=buildff("RESULTADO_RESULTADO.xlsx")
x=pd.DataFrame() #fase grupos
xff=pd.DataFrame() #fase final
for file in filter(lambda k: k.endswith('.xlsx') or k.endswith('.xls'), next(walk(dire))[2][:]):
  z=buildx(file)
  ff=buildff(file)  
  z = pd.concat([z,r],axis=1) 
 
  z.columns = ['xt1','xg1','xg2','xt2','idx','namex','rt1','rg1','rg2','rt2','idr','namer']  
  x = x.append(z)
  ff = pd.concat([ff,rff],axis=1) 
  #display(ff.head())
  ff.columns = ['xlabel','xvalue','keyx','idx','rlabel','rvalue','rid','keyr',]  
  xff = xff.append(ff)  

x['points'] =  pd.Series(x.apply(lambda x:points(x.xg1,x.xg2,x.rg1,x.rg2),axis = 1))
x['incompletes'] =  pd.Series(x.apply(lambda x:incomplete(x.xg1,x.xg2),axis = 1))
xff['incompletes'] =  pd.Series(xff.apply(lambda x:incompleteff(x.xlabel,x.xvalue),axis = 1))
xff['points'] =  pd.Series(xff.apply(lambda x:pointsff(x.idx,x.xlabel,x.xvalue,x.rlabel,x.rvalue,x.keyx,x.keyr),axis = 1))
#display(xff.head())
tabla = x.groupby(['idx']).sum().reset_index()
tablaff = xff.groupby(['idx']).sum().reset_index()
#display(tablaff.head())


tabla['seller'] =  pd.Series(tabla.apply(lambda tabla:seller(tabla.idx),axis = 1))
tabla['name'] =  pd.Series(tabla.apply(lambda tabla:name(tabla.idx),axis = 1))
tabla['name2'] =  pd.Series(tabla.apply(lambda tabla:name2(tabla.idx),axis = 1))
tabla['one'] =  pd.Series(tabla.apply(lambda tabla:one(),axis = 1))
tablaff['seller'] =  pd.Series(tabla.apply(lambda tabla:seller(tabla.idx),axis = 1))
tablaff['one'] =  pd.Series(tabla.apply(lambda tabla:one(),axis = 1))



#tabla1 = tabla.sort_values(['incompletes'], ascending=False)[['seller','points','incompletes','idx']]
tablaff1 = tablaff.sort_values(['points'], ascending=False)[['points','seller','incompletes','idx']]

#display (tablaff1.head())
#print ('total='+str(tabla1.shape[0]))

#display(tabla1[tabla1['seller']=='JonathanMurana'])    #
#display (tabla1.head())    

tabla2 = tabla.sort_values(['points'], ascending=False)[['name2','seller','points','idx']]
tabla2=tabla2.reset_index()
#display(tabla2[tabla2['seller']=='JonathanMurana'])    #

tabla2ff = tablaff1.sort_values(['points'], ascending=False)[['idx','points']]
tabla2ff=tabla2ff.reset_index()
tabla2ff.columns = ['index','idx','points2']  

#tabla2['pos']=tabla2.index
display (tabla2.head()) 
display (tabla2ff.head()) 

tablazz =  pd.merge(tabla2, tabla2ff, how='outer', on=['idx'])






#ranking = tabla.groupby(['seller']).sum().reset_index()
#ranking = ranking.sort_values(['one'], ascending=False)[['seller','one']]
#print(ranking)
#tabla2.style



#tabla2.style.set_properties(**{'background-color': 'black',
#                           'color': 'lawngreen',
#                           'border-color': 'white'})

#print(html)
#<head><meta charset="utf-8" />
#tabla2.to_html()
tabla3=tabla2[['name2','seller','points']]
#tabla3.to_json(open('my_file.html', 'w'),orient=split)

claveAnterior='Suiza(2)-CostaRica(2)_y_Brasil(2)-Serbia(0)'
clave='Belgica(1)-Inglaterra(0)_y_Panama(1)-Tunez(2)'


tablazz['total'] =  pd.Series(tablazz.apply(lambda tablazz:total(tablazz.points,tablazz.points2),axis = 1))
tablazz = tablazz.sort_values(['total'], ascending=False)
display (tablazz)
tabla3 = tablazz
tabla3_filtered = tabla3[tabla3.seller!='RESULTADO']
data='../penca-argos/src/assets/data_' + clave + '.json'

dataAnterior='../penca-argos/src/assets/data_' + claveAnterior + '.json'

tabla3_filtered_viejo=pd.DataFrame()
tabla3_filtered_viejo = pd.read_json(orient='records',path_or_buf=open(dataAnterior, 'r'))


#print (tabla3_filtered.index)
#print (tabla3_filtered_viejo.index)



#tabla3_filtered['last_index'] =   pd.Series(tabla3_filtered.apply\
#                                            (lambda tabla3_filtered:myindex(tabla3_filtered\
#                                                                            .name2,tabla3_filtered_viejo),axis = 1))


#pd.Series(tabla3_filtered_viejo.apply\
#                                      (lambda tabla3_filtered_viejo:speed(tabla3_filtered_viejo),axis = 1))

#print(tabla3_filtered_viejo[tabla3_filtered_viejo['name2']=='Ernesto RUTING'].index)


tabla3_filtered.to_json(orient='records',path_or_buf=open(data, 'w'))

file = open('../penca-argos/src/assets/config.json','w') 
config='{"clave":"' + clave + '"}'
file.write(config) 
file.close() 

#tabla3_filtered.to_csv(open('penca_argos_hasta_Rusia(3)-Egipto(1).csv', 'w'))
# Out:
#       label  value             key1  \
# 4   Uruguay    1.0   Uruguay-España
# 5    España    0.0   Uruguay-España
# 7   Francia    3.0  Francia-Nigeria
# 8   Nigeria    1.0  Francia-Nigeria
# 11    Suiza    0.0     Suiza-México
#
#                                                    id      label  value  \
# 4   Mauro_ 10 (CM2).xlsx|Carolina Mallo|carolina63...    Uruguay    NaN
# 5   Mauro_ 10 (CM2).xlsx|Carolina Mallo|carolina63...   Portugal    NaN
# 7   Mauro_ 10 (CM2).xlsx|Carolina Mallo|carolina63...    Francia    NaN
# 8   Mauro_ 10 (CM2).xlsx|Carolina Mallo|carolina63...  Argentina    NaN
# 11  Mauro_ 10 (CM2).xlsx|Carolina Mallo|carolina63...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value            key1  \
# 4      Rusia    0.0  Rusia-Portugal
# 5   Portugal    2.0  Rusia-Portugal
# 7       Perú    2.0    Perú-Croacia
# 8    Croacia    1.0    Perú-Croacia
# 11    Brasil    1.0   Brasil-México
#
#                                                    id      label  value  \
# 4   Pancho_MBiganzoli2.xlsx|Martín Biganzoli|mbiga...    Uruguay    NaN
# 5   Pancho_MBiganzoli2.xlsx|Martín Biganzoli|mbiga...   Portugal    NaN
# 7   Pancho_MBiganzoli2.xlsx|Martín Biganzoli|mbiga...    Francia    NaN
# 8   Pancho_MBiganzoli2.xlsx|Martín Biganzoli|mbiga...  Argentina    NaN
# 11  Pancho_MBiganzoli2.xlsx|Martín Biganzoli|mbiga...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#         label  value               key1  \
# 4     Uruguay    1.0     Uruguay-España
# 5      España    0.0     Uruguay-España
# 7     Francia    1.0  Francia-Argentina
# 8   Argentina    0.0  Francia-Argentina
# 11     Brasil    2.0      Brasil-México
#
#                                                    id      label  value  \
# 4   Mauro_ 15 (MF).xlsx|Matias Fernández|matiferce...    Uruguay    NaN
# 5   Mauro_ 15 (MF).xlsx|Matias Fernández|matiferce...   Portugal    NaN
# 7   Mauro_ 15 (MF).xlsx|Matias Fernández|matiferce...    Francia    NaN
# 8   Mauro_ 15 (MF).xlsx|Matias Fernández|matiferce...  Argentina    NaN
# 11  Mauro_ 15 (MF).xlsx|Matias Fernández|matiferce...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value                  key1  \
# 4    Uruguay    2.0      Uruguay-Portugal
# 5   Portugal    1.0      Uruguay-Portugal
# 7    Francia    2.0       Francia-Croacia
# 8    Croacia    0.0       Francia-Croacia
# 11    Brasil    3.0  Brasil-Corea del Sur
#
#                                                    id      label  value  \
# 4   LucasBouissa_3_RicardoKoster.xlsx|RICARDO KÖST...    Uruguay    NaN
# 5   LucasBouissa_3_RicardoKoster.xlsx|RICARDO KÖST...   Portugal    NaN
# 7   LucasBouissa_3_RicardoKoster.xlsx|RICARDO KÖST...    Francia    NaN
# 8   LucasBouissa_3_RicardoKoster.xlsx|RICARDO KÖST...  Argentina    NaN
# 11  LucasBouissa_3_RicardoKoster.xlsx|RICARDO KÖST...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#       label  value             key1  \
# 4   Uruguay    2.0   Uruguay-España
# 5    España    1.0   Uruguay-España
# 7   Francia    0.0  Francia-Croacia
# 8   Croacia    2.0  Francia-Croacia
# 11   Brasil    3.0    Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Javier Hernández_18_Marcelo Caraballo.xlsx|Mar...    Uruguay    NaN
# 5   Javier Hernández_18_Marcelo Caraballo.xlsx|Mar...   Portugal    NaN
# 7   Javier Hernández_18_Marcelo Caraballo.xlsx|Mar...    Francia    NaN
# 8   Javier Hernández_18_Marcelo Caraballo.xlsx|Mar...  Argentina    NaN
# 11  Javier Hernández_18_Marcelo Caraballo.xlsx|Mar...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#       label  value             key1  \
# 4   Uruguay    1.0   Uruguay-España
# 5    España    1.0   Uruguay-España
# 7   Francia    2.0  Francia-Croacia
# 8   Croacia    2.0  Francia-Croacia
# 11   Brasil    2.0    Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Penca Argos Rusia 2018 AgustinPerez_3_LeandroV...    Uruguay    NaN
# 5   Penca Argos Rusia 2018 AgustinPerez_3_LeandroV...   Portugal    NaN
# 7   Penca Argos Rusia 2018 AgustinPerez_3_LeandroV...    Francia    NaN
# 8   Penca Argos Rusia 2018 AgustinPerez_3_LeandroV...  Argentina    NaN
# 11  Penca Argos Rusia 2018 AgustinPerez_3_LeandroV...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value             key1  \
# 4      Rusia    1.0   Rusia-Portugal
# 5   Portugal    0.0   Rusia-Portugal
# 7    Francia    2.0  Francia-Nigeria
# 8    Nigeria    1.0  Francia-Nigeria
# 11    Brasil    2.0    Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Penca Argos Rusia 2018 AgustinPerez_7_Alexande...    Uruguay    NaN
# 5   Penca Argos Rusia 2018 AgustinPerez_7_Alexande...   Portugal    NaN
# 7   Penca Argos Rusia 2018 AgustinPerez_7_Alexande...    Francia    NaN
# 8   Penca Argos Rusia 2018 AgustinPerez_7_Alexande...  Argentina    NaN
# 11  Penca Argos Rusia 2018 AgustinPerez_7_Alexande...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    1.0    Uruguay-España
# 5     España    1.0    Uruguay-España
# 7    Francia    2.0  Francia-Islandia
# 8   Islandia    0.0  Francia-Islandia
# 11    Brasil    3.0     Brasil-México
#
#                                                    id      label  value  \
# 4   Pancho_FedeDoreste.xlsx|Federico Doreste|fede....    Uruguay    NaN
# 5   Pancho_FedeDoreste.xlsx|Federico Doreste|fede....   Portugal    NaN
# 7   Pancho_FedeDoreste.xlsx|Federico Doreste|fede....    Francia    NaN
# 8   Pancho_FedeDoreste.xlsx|Federico Doreste|fede....  Argentina    NaN
# 11  Pancho_FedeDoreste.xlsx|Federico Doreste|fede....     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    2.0  Uruguay-Portugal
# 5   Portugal    1.0  Uruguay-Portugal
# 7    Francia    2.0   Francia-Croacia
# 8    Croacia    0.0   Francia-Croacia
# 11    Brasil    3.0     Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Mauro_ 7 (FA).xlsx|FRANCO AMACORIA|franco31219...    Uruguay    NaN
# 5   Mauro_ 7 (FA).xlsx|FRANCO AMACORIA|franco31219...   Portugal    NaN
# 7   Mauro_ 7 (FA).xlsx|FRANCO AMACORIA|franco31219...    Francia    NaN
# 8   Mauro_ 7 (FA).xlsx|FRANCO AMACORIA|franco31219...  Argentina    NaN
# 11  Mauro_ 7 (FA).xlsx|FRANCO AMACORIA|franco31219...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    1.0  Uruguay-Portugal
# 5   Portugal    0.0  Uruguay-Portugal
# 7    Francia    2.0   Francia-Nigeria
# 8    Nigeria    0.0   Francia-Nigeria
# 11    Brasil    3.0     Brasil-México
#
#                                                    id      label  value  \
# 4   Javier Hernández_25_Gabriel Bulla.xlsx|Gabriel...    Uruguay    NaN
# 5   Javier Hernández_25_Gabriel Bulla.xlsx|Gabriel...   Portugal    NaN
# 7   Javier Hernández_25_Gabriel Bulla.xlsx|Gabriel...    Francia    NaN
# 8   Javier Hernández_25_Gabriel Bulla.xlsx|Gabriel...  Argentina    NaN
# 11  Javier Hernández_25_Gabriel Bulla.xlsx|Gabriel...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value                  key1  \
# 4    Uruguay    1.0      Uruguay-Portugal
# 5   Portugal    0.0      Uruguay-Portugal
# 7    Francia    2.0       Francia-Nigeria
# 8    Nigeria    1.0       Francia-Nigeria
# 11    Brasil    4.0  Brasil-Corea del Sur
#
#                                                    id      label  value  \
# 4   LucasBouissa_24_RickyCalvo.xlsx|Ricardo Calvo|...    Uruguay    NaN
# 5   LucasBouissa_24_RickyCalvo.xlsx|Ricardo Calvo|...   Portugal    NaN
# 7   LucasBouissa_24_RickyCalvo.xlsx|Ricardo Calvo|...    Francia    NaN
# 8   LucasBouissa_24_RickyCalvo.xlsx|Ricardo Calvo|...  Argentina    NaN
# 11  LucasBouissa_24_RickyCalvo.xlsx|Ricardo Calvo|...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    2.0  Uruguay-Portugal
# 5   Portugal    0.0  Uruguay-Portugal
# 7    Francia    3.0   Francia-Croacia
# 8    Croacia    1.0   Francia-Croacia
# 11    Brasil    4.0     Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Penca Argos Rusia 2018 - ErnestoRoca_5_Santiag...    Uruguay    NaN
# 5   Penca Argos Rusia 2018 - ErnestoRoca_5_Santiag...   Portugal    NaN
# 7   Penca Argos Rusia 2018 - ErnestoRoca_5_Santiag...    Francia    NaN
# 8   Penca Argos Rusia 2018 - ErnestoRoca_5_Santiag...  Argentina    NaN
# 11  Penca Argos Rusia 2018 - ErnestoRoca_5_Santiag...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#         label  value               key1  \
# 4     Uruguay    2.0  Uruguay-Marruecos
# 5   Marruecos    0.0  Uruguay-Marruecos
# 7     Francia    2.0    Francia-Nigeria
# 8     Nigeria    1.0    Francia-Nigeria
# 11     Brasil    3.0      Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Penca Argos Rusia 2018 AgustinPerez_9_Nicolas ...    Uruguay    NaN
# 5   Penca Argos Rusia 2018 AgustinPerez_9_Nicolas ...   Portugal    NaN
# 7   Penca Argos Rusia 2018 AgustinPerez_9_Nicolas ...    Francia    NaN
# 8   Penca Argos Rusia 2018 AgustinPerez_9_Nicolas ...  Argentina    NaN
# 11  Penca Argos Rusia 2018 AgustinPerez_9_Nicolas ...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#       label  value             key1  \
# 4   Uruguay    2.0   Uruguay-España
# 5    España    1.0   Uruguay-España
# 7   Francia    3.0  Francia-Nigeria
# 8   Nigeria    0.0  Francia-Nigeria
# 11   Brasil    2.0    Brasil-México
#
#                                                    id      label  value  \
# 4   Paolo De Franco_ Paolo De Franco.xlsx|PAOLO DE...    Uruguay    NaN
# 5   Paolo De Franco_ Paolo De Franco.xlsx|PAOLO DE...   Portugal    NaN
# 7   Paolo De Franco_ Paolo De Franco.xlsx|PAOLO DE...    Francia    NaN
# 8   Paolo De Franco_ Paolo De Franco.xlsx|PAOLO DE...  Argentina    NaN
# 11  Paolo De Franco_ Paolo De Franco.xlsx|PAOLO DE...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    2.0  Uruguay-Portugal
# 5   Portugal    1.0  Uruguay-Portugal
# 7    Francia    2.0   Francia-Croacia
# 8    Croacia    0.0   Francia-Croacia
# 11    Brasil    3.0     Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Penca Argos Rusia 2018 - ErnestoRoca_7_Ernesto...    Uruguay    NaN
# 5   Penca Argos Rusia 2018 - ErnestoRoca_7_Ernesto...   Portugal    NaN
# 7   Penca Argos Rusia 2018 - ErnestoRoca_7_Ernesto...    Francia    NaN
# 8   Penca Argos Rusia 2018 - ErnestoRoca_7_Ernesto...  Argentina    NaN
# 11  Penca Argos Rusia 2018 - ErnestoRoca_7_Ernesto...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    2.0  Uruguay-Portugal
# 5   Portugal    1.0  Uruguay-Portugal
# 7       Perú    0.0      Perú-Nigeria
# 8    Nigeria    1.0      Perú-Nigeria
# 11    Brasil    3.0     Brasil-México
#
#                                                    id      label  value  \
# 4   Paolo De Franco_ Sergio Vitola.xlsx|SERGIO VIT...    Uruguay    NaN
# 5   Paolo De Franco_ Sergio Vitola.xlsx|SERGIO VIT...   Portugal    NaN
# 7   Paolo De Franco_ Sergio Vitola.xlsx|SERGIO VIT...    Francia    NaN
# 8   Paolo De Franco_ Sergio Vitola.xlsx|SERGIO VIT...  Argentina    NaN
# 11  Paolo De Franco_ Sergio Vitola.xlsx|SERGIO VIT...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value                  key1  \
# 4    Uruguay    2.0      Uruguay-Portugal
# 5   Portugal    1.0      Uruguay-Portugal
# 7    Francia    2.0       Francia-Nigeria
# 8    Nigeria    0.0       Francia-Nigeria
# 11    Brasil    3.0  Brasil-Corea del Sur
#
#                                                    id      label  value  \
# 4   Penca Argos Rusia 2018 - FrankoGraziano_8_Rafa...    Uruguay    NaN
# 5   Penca Argos Rusia 2018 - FrankoGraziano_8_Rafa...   Portugal    NaN
# 7   Penca Argos Rusia 2018 - FrankoGraziano_8_Rafa...    Francia    NaN
# 8   Penca Argos Rusia 2018 - FrankoGraziano_8_Rafa...  Argentina    NaN
# 11  Penca Argos Rusia 2018 - FrankoGraziano_8_Rafa...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#         label  value               key1  \
# 4     Uruguay    1.0  Uruguay-Marruecos
# 5   Marruecos    0.0  Uruguay-Marruecos
# 7     Francia    2.0    Francia-Croacia
# 8     Croacia    1.0    Francia-Croacia
# 11     Brasil    4.0      Brasil-México
#
#                                                    id      label  value  \
# 4   Mauro_3 (RP).xlsx|Rafael Pérez|rafael.perez@mi...    Uruguay    NaN
# 5   Mauro_3 (RP).xlsx|Rafael Pérez|rafael.perez@mi...   Portugal    NaN
# 7   Mauro_3 (RP).xlsx|Rafael Pérez|rafael.perez@mi...    Francia    NaN
# 8   Mauro_3 (RP).xlsx|Rafael Pérez|rafael.perez@mi...  Argentina    NaN
# 11  Mauro_3 (RP).xlsx|Rafael Pérez|rafael.perez@mi...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    1.0  Uruguay-Portugal
# 5   Portugal    1.0  Uruguay-Portugal
# 7    Francia    2.0   Francia-Croacia
# 8    Croacia    1.0   Francia-Croacia
# 11    Brasil    3.0     Brasil-México
#
#                                                    id      label  value  \
# 4   Galvao_Penca Argos Rusia 2018_A-Menini_02 GALV...    Uruguay    NaN
# 5   Galvao_Penca Argos Rusia 2018_A-Menini_02 GALV...   Portugal    NaN
# 7   Galvao_Penca Argos Rusia 2018_A-Menini_02 GALV...    Francia    NaN
# 8   Galvao_Penca Argos Rusia 2018_A-Menini_02 GALV...  Argentina    NaN
# 11  Galvao_Penca Argos Rusia 2018_A-Menini_02 GALV...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#         label  value               key1  \
# 4     Uruguay    0.0     Uruguay-España
# 5      España    1.0     Uruguay-España
# 7     Francia    1.0  Francia-Argentina
# 8   Argentina    2.0  Francia-Argentina
# 11     Brasil    3.0      Brasil-México
#
#                                                    id      label  value  \
# 4   Penca Argos Rusia 2018 - FedericoArmandPilon_2...    Uruguay    NaN
# 5   Penca Argos Rusia 2018 - FedericoArmandPilon_2...   Portugal    NaN
# 7   Penca Argos Rusia 2018 - FedericoArmandPilon_2...    Francia    NaN
# 8   Penca Argos Rusia 2018 - FedericoArmandPilon_2...  Argentina    NaN
# 11  Penca Argos Rusia 2018 - FedericoArmandPilon_2...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#         label  value            key1  \
# 4     Uruguay    1.0  Uruguay-España
# 5      España    1.0  Uruguay-España
# 7        Perú    1.0  Perú-Argentina
# 8   Argentina    0.0  Perú-Argentina
# 11     Brasil    2.0   Brasil-México
#
#                                                    id      label  value  \
# 4   Pancho_SofiaMastandrea.xlsx|Sofía M|sofiamasta...    Uruguay    NaN
# 5   Pancho_SofiaMastandrea.xlsx|Sofía M|sofiamasta...   Portugal    NaN
# 7   Pancho_SofiaMastandrea.xlsx|Sofía M|sofiamasta...    Francia    NaN
# 8   Pancho_SofiaMastandrea.xlsx|Sofía M|sofiamasta...  Argentina    NaN
# 11  Pancho_SofiaMastandrea.xlsx|Sofía M|sofiamasta...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    1.0  Uruguay-Portugal
# 5   Portugal    1.0  Uruguay-Portugal
# 7    Francia    4.0  Francia-Islandia
# 8   Islandia    0.0  Francia-Islandia
# 11    Brasil    2.0     Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Javier Hernández_6_Cecilia Amorena.xlsx|Ma. Ce...    Uruguay    NaN
# 5   Javier Hernández_6_Cecilia Amorena.xlsx|Ma. Ce...   Portugal    NaN
# 7   Javier Hernández_6_Cecilia Amorena.xlsx|Ma. Ce...    Francia    NaN
# 8   Javier Hernández_6_Cecilia Amorena.xlsx|Ma. Ce...  Argentina    NaN
# 11  Javier Hernández_6_Cecilia Amorena.xlsx|Ma. Ce...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#       label  value             key1  \
# 4   Uruguay    1.0   Uruguay-España
# 5    España    1.0   Uruguay-España
# 7   Francia    1.0  Francia-Nigeria
# 8   Nigeria    0.0  Francia-Nigeria
# 11   Brasil    2.0    Brasil-México
#
#                                                    id      label  value  \
# 4   LucasBouissa_11_AnthonyVillas.xlsx|Anthony Vil...    Uruguay    NaN
# 5   LucasBouissa_11_AnthonyVillas.xlsx|Anthony Vil...   Portugal    NaN
# 7   LucasBouissa_11_AnthonyVillas.xlsx|Anthony Vil...    Francia    NaN
# 8   LucasBouissa_11_AnthonyVillas.xlsx|Anthony Vil...  Argentina    NaN
# 11  LucasBouissa_11_AnthonyVillas.xlsx|Anthony Vil...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value             key1  \
# 4      Rusia    1.0   Rusia-Portugal
# 5   Portugal    2.0   Rusia-Portugal
# 7    Francia    3.0  Francia-Nigeria
# 8    Nigeria    1.0  Francia-Nigeria
# 11    Brasil    3.0    Brasil-Suecia
#
#                                                    id      label  value  \
# 4   MarianoMartinez_5_EnriqueVentura.xlsx|Enrique ...    Uruguay    NaN
# 5   MarianoMartinez_5_EnriqueVentura.xlsx|Enrique ...   Portugal    NaN
# 7   MarianoMartinez_5_EnriqueVentura.xlsx|Enrique ...    Francia    NaN
# 8   MarianoMartinez_5_EnriqueVentura.xlsx|Enrique ...  Argentina    NaN
# 11  MarianoMartinez_5_EnriqueVentura.xlsx|Enrique ...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    2.0  Uruguay-Portugal
# 5   Portugal    1.0  Uruguay-Portugal
# 7    Francia    1.0   Francia-Nigeria
# 8    Nigeria    0.0   Francia-Nigeria
# 11    Brasil    3.0     Brasil-México
#
#                                                    id      label  value  \
# 4   MateoGonnet_10_SantiagoAPilon.xlsx|Santiago Ar...    Uruguay    NaN
# 5   MateoGonnet_10_SantiagoAPilon.xlsx|Santiago Ar...   Portugal    NaN
# 7   MateoGonnet_10_SantiagoAPilon.xlsx|Santiago Ar...    Francia    NaN
# 8   MateoGonnet_10_SantiagoAPilon.xlsx|Santiago Ar...  Argentina    NaN
# 11  MateoGonnet_10_SantiagoAPilon.xlsx|Santiago Ar...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value                  key1  \
# 4    Uruguay    2.0      Uruguay-Portugal
# 5   Portugal    1.0      Uruguay-Portugal
# 7    Francia    2.0       Francia-Nigeria
# 8    Nigeria    0.0       Francia-Nigeria
# 11    Brasil    3.0  Brasil-Corea del Sur
#
#                                                    id      label  value  \
# 4   JonathanMurana_TatianaAlvarez.xlsx|Tatiana Álv...    Uruguay    NaN
# 5   JonathanMurana_TatianaAlvarez.xlsx|Tatiana Álv...   Portugal    NaN
# 7   JonathanMurana_TatianaAlvarez.xlsx|Tatiana Álv...    Francia    NaN
# 8   JonathanMurana_TatianaAlvarez.xlsx|Tatiana Álv...  Argentina    NaN
# 11  JonathanMurana_TatianaAlvarez.xlsx|Tatiana Álv...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    1.0  Uruguay-Portugal
# 5   Portugal    1.0  Uruguay-Portugal
# 7    Francia    3.0   Francia-Croacia
# 8    Croacia    1.0   Francia-Croacia
# 11    Brasil    3.0     Brasil-México
#
#                                                    id      label  value  \
# 4   MarianoMartinez_9_TataMartinez.xlsx|Ramiro "Ta...    Uruguay    NaN
# 5   MarianoMartinez_9_TataMartinez.xlsx|Ramiro "Ta...   Portugal    NaN
# 7   MarianoMartinez_9_TataMartinez.xlsx|Ramiro "Ta...    Francia    NaN
# 8   MarianoMartinez_9_TataMartinez.xlsx|Ramiro "Ta...  Argentina    NaN
# 11  MarianoMartinez_9_TataMartinez.xlsx|Ramiro "Ta...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value                  key1  \
# 4    Uruguay    2.0      Uruguay-Portugal
# 5   Portugal    1.0      Uruguay-Portugal
# 7    Francia    3.0       Francia-Nigeria
# 8    Nigeria    1.0       Francia-Nigeria
# 11    Brasil    2.0  Brasil-Corea del Sur
#
#                                                    id      label  value  \
# 4   Paolo De Franco_Flor Iraola.xlsx|MA. FLORENCIA...    Uruguay    NaN
# 5   Paolo De Franco_Flor Iraola.xlsx|MA. FLORENCIA...   Portugal    NaN
# 7   Paolo De Franco_Flor Iraola.xlsx|MA. FLORENCIA...    Francia    NaN
# 8   Paolo De Franco_Flor Iraola.xlsx|MA. FLORENCIA...  Argentina    NaN
# 11  Paolo De Franco_Flor Iraola.xlsx|MA. FLORENCIA...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    3.0  Uruguay-Portugal
# 5   Portugal    1.0  Uruguay-Portugal
# 7    Francia    2.0   Francia-Croacia
# 8    Croacia    1.0   Francia-Croacia
# 11    Brasil    4.0     Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Nicolás Fripp_10_NicolásFripp2.xlsx|Nicolás Fr...    Uruguay    NaN
# 5   Nicolás Fripp_10_NicolásFripp2.xlsx|Nicolás Fr...   Portugal    NaN
# 7   Nicolás Fripp_10_NicolásFripp2.xlsx|Nicolás Fr...    Francia    NaN
# 8   Nicolás Fripp_10_NicolásFripp2.xlsx|Nicolás Fr...  Argentina    NaN
# 11  Nicolás Fripp_10_NicolásFripp2.xlsx|Nicolás Fr...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    3.0  Uruguay-Portugal
# 5   Portugal    2.0  Uruguay-Portugal
# 7       Perú    2.0      Perú-Nigeria
# 8    Nigeria    1.0      Perú-Nigeria
# 11    Brasil    3.0     Brasil-Suecia
#
#                                                    id      label  value  \
# 4   JonathanMurana_JimenaMuraña.xlsx|Jimena Muraña...    Uruguay    NaN
# 5   JonathanMurana_JimenaMuraña.xlsx|Jimena Muraña...   Portugal    NaN
# 7   JonathanMurana_JimenaMuraña.xlsx|Jimena Muraña...    Francia    NaN
# 8   JonathanMurana_JimenaMuraña.xlsx|Jimena Muraña...  Argentina    NaN
# 11  JonathanMurana_JimenaMuraña.xlsx|Jimena Muraña...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    3.0  Uruguay-Portugal
# 5   Portugal    1.0  Uruguay-Portugal
# 7    Francia    2.0   Francia-Croacia
# 8    Croacia    3.0   Francia-Croacia
# 11    Brasil    3.0     Brasil-Suecia
#
#                                                    id      label  value  \
# 4   NicolásFripp_13_GustavoFripp.xlsx|Gustavo Frip...    Uruguay    NaN
# 5   NicolásFripp_13_GustavoFripp.xlsx|Gustavo Frip...   Portugal    NaN
# 7   NicolásFripp_13_GustavoFripp.xlsx|Gustavo Frip...    Francia    NaN
# 8   NicolásFripp_13_GustavoFripp.xlsx|Gustavo Frip...  Argentina    NaN
# 11  NicolásFripp_13_GustavoFripp.xlsx|Gustavo Frip...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#       label  value             key1  \
# 4   Uruguay    2.0   Uruguay-España
# 5    España    1.0   Uruguay-España
# 7   Francia    3.0  Francia-Nigeria
# 8   Nigeria    0.0  Francia-Nigeria
# 11   Brasil    2.0    Brasil-México
#
#                                                    id      label  value  \
# 4   Mathias Legarreta_05.xlsx|Mathias Legarreta|ma...    Uruguay    NaN
# 5   Mathias Legarreta_05.xlsx|Mathias Legarreta|ma...   Portugal    NaN
# 7   Mathias Legarreta_05.xlsx|Mathias Legarreta|ma...    Francia    NaN
# 8   Mathias Legarreta_05.xlsx|Mathias Legarreta|ma...  Argentina    NaN
# 11  Mathias Legarreta_05.xlsx|Mathias Legarreta|ma...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    3.0  Uruguay-Portugal
# 5   Portugal    2.0  Uruguay-Portugal
# 7    Francia    2.0   Francia-Croacia
# 8    Croacia    0.0   Francia-Croacia
# 11    Brasil    2.0     Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Galvao_Penca Argos Rusia 2018 ECuello GALVAO 6...    Uruguay    NaN
# 5   Galvao_Penca Argos Rusia 2018 ECuello GALVAO 6...   Portugal    NaN
# 7   Galvao_Penca Argos Rusia 2018 ECuello GALVAO 6...    Francia    NaN
# 8   Galvao_Penca Argos Rusia 2018 ECuello GALVAO 6...  Argentina    NaN
# 11  Galvao_Penca Argos Rusia 2018 ECuello GALVAO 6...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    3.0  Uruguay-Portugal
# 5   Portugal    1.0  Uruguay-Portugal
# 7    Francia    3.0   Francia-Nigeria
# 8    Nigeria    0.0   Francia-Nigeria
# 11    Brasil    5.0     Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Mauro_ 9 (JP).xlsx|Jessica Padilla|ekkapadilla...    Uruguay    NaN
# 5   Mauro_ 9 (JP).xlsx|Jessica Padilla|ekkapadilla...   Portugal    NaN
# 7   Mauro_ 9 (JP).xlsx|Jessica Padilla|ekkapadilla...    Francia    NaN
# 8   Mauro_ 9 (JP).xlsx|Jessica Padilla|ekkapadilla...  Argentina    NaN
# 11  Mauro_ 9 (JP).xlsx|Jessica Padilla|ekkapadilla...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#         label  value               key1  \
# 4      Egipto    1.0      Egipto-España
# 5      España    3.0      Egipto-España
# 7     Francia    2.0  Francia-Argentina
# 8   Argentina    1.0  Francia-Argentina
# 11     Brasil    3.0      Brasil-México
#
#                                                    id      label  value  \
# 4   Penca Argos Rusia 2018 - FrankoGraziano_7_Nata...    Uruguay    NaN
# 5   Penca Argos Rusia 2018 - FrankoGraziano_7_Nata...   Portugal    NaN
# 7   Penca Argos Rusia 2018 - FrankoGraziano_7_Nata...    Francia    NaN
# 8   Penca Argos Rusia 2018 - FrankoGraziano_7_Nata...  Argentina    NaN
# 11  Penca Argos Rusia 2018 - FrankoGraziano_7_Nata...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#       label  value             key1  \
# 4   Uruguay    0.0   Uruguay-España
# 5    España    1.0   Uruguay-España
# 7   Francia    2.0  Francia-Croacia
# 8   Croacia    0.0  Francia-Croacia
# 11   Brasil    2.0    Brasil-México
#
#                                                    id      label  value  \
# 4   Mathias Legarreta_ 01.xlsx|Mathias Legarreta|m...    Uruguay    NaN
# 5   Mathias Legarreta_ 01.xlsx|Mathias Legarreta|m...   Portugal    NaN
# 7   Mathias Legarreta_ 01.xlsx|Mathias Legarreta|m...    Francia    NaN
# 8   Mathias Legarreta_ 01.xlsx|Mathias Legarreta|m...  Argentina    NaN
# 11  Mathias Legarreta_ 01.xlsx|Mathias Legarreta|m...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#         label  value               key1  \
# 4     Uruguay    2.0     Uruguay-España
# 5      España    1.0     Uruguay-España
# 7     Francia    3.0  Francia-Argentina
# 8   Argentina    2.0  Francia-Argentina
# 11     Brasil    3.0      Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Javier Hernández_15_Juan José De León.xlsx|JUA...    Uruguay    NaN
# 5   Javier Hernández_15_Juan José De León.xlsx|JUA...   Portugal    NaN
# 7   Javier Hernández_15_Juan José De León.xlsx|JUA...    Francia    NaN
# 8   Javier Hernández_15_Juan José De León.xlsx|JUA...  Argentina    NaN
# 11  Javier Hernández_15_Juan José De León.xlsx|JUA...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value             key1  \
# 4      Rusia    1.0   Rusia-Portugal
# 5   Portugal    2.0   Rusia-Portugal
# 7    Francia    2.0  Francia-Croacia
# 8    Croacia    1.0  Francia-Croacia
# 11    Brasil    2.0    Brasil-México
#
#                                                    id      label  value  \
# 4   MateoGonnet_1_MatiasPoloni.xlsx|Matías Poloni|...    Uruguay    NaN
# 5   MateoGonnet_1_MatiasPoloni.xlsx|Matías Poloni|...   Portugal    NaN
# 7   MateoGonnet_1_MatiasPoloni.xlsx|Matías Poloni|...    Francia    NaN
# 8   MateoGonnet_1_MatiasPoloni.xlsx|Matías Poloni|...  Argentina    NaN
# 11  MateoGonnet_1_MatiasPoloni.xlsx|Matías Poloni|...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value                  key1  \
# 4    Uruguay    2.0      Uruguay-Portugal
# 5   Portugal    1.0      Uruguay-Portugal
# 7       Perú    1.0          Perú-Nigeria
# 8    Nigeria    1.0          Perú-Nigeria
# 11    Brasil    3.0  Brasil-Corea del Sur
#
#                                                    id      label  value  \
# 4   Pancho_FedericoFiorito.xlsx|Federico Fioritto|...    Uruguay    NaN
# 5   Pancho_FedericoFiorito.xlsx|Federico Fioritto|...   Portugal    NaN
# 7   Pancho_FedericoFiorito.xlsx|Federico Fioritto|...    Francia    NaN
# 8   Pancho_FedericoFiorito.xlsx|Federico Fioritto|...  Argentina    NaN
# 11  Pancho_FedericoFiorito.xlsx|Federico Fioritto|...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#       label  value             key1  \
# 4   Uruguay    2.0   Uruguay-España
# 5    España    3.0   Uruguay-España
# 7   Francia    2.0  Francia-Croacia
# 8   Croacia    0.0  Francia-Croacia
# 11   Brasil    2.0    Brasil-México
#
#                                                    id      label  value  \
# 4   Penca Argos Rusia 2018 - FedericoArmandPilon_8...    Uruguay    NaN
# 5   Penca Argos Rusia 2018 - FedericoArmandPilon_8...   Portugal    NaN
# 7   Penca Argos Rusia 2018 - FedericoArmandPilon_8...    Francia    NaN
# 8   Penca Argos Rusia 2018 - FedericoArmandPilon_8...  Argentina    NaN
# 11  Penca Argos Rusia 2018 - FedericoArmandPilon_8...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    2.0  Uruguay-Portugal
# 5   Portugal    1.0  Uruguay-Portugal
# 7    Francia    2.0   Francia-Nigeria
# 8    Nigeria    0.0   Francia-Nigeria
# 11    Brasil    1.0     Brasil-México
#
#                                                    id      label  value  \
# 4   Penca Argos Rusia 2018 - FrankoGraziano_3_Guzm...    Uruguay    NaN
# 5   Penca Argos Rusia 2018 - FrankoGraziano_3_Guzm...   Portugal    NaN
# 7   Penca Argos Rusia 2018 - FrankoGraziano_3_Guzm...    Francia    NaN
# 8   Penca Argos Rusia 2018 - FrankoGraziano_3_Guzm...  Argentina    NaN
# 11  Penca Argos Rusia 2018 - FrankoGraziano_3_Guzm...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value                  key1  \
# 4    Uruguay    1.0      Uruguay-Portugal
# 5   Portugal    1.0      Uruguay-Portugal
# 7    Francia    2.0       Francia-Croacia
# 8    Croacia    1.0       Francia-Croacia
# 11    Brasil    3.0  Brasil-Corea del Sur
#
#                                                    id      label  value  \
# 4   JonathanMurana_MartinViurrarena.xlsx|Martin Vi...    Uruguay    NaN
# 5   JonathanMurana_MartinViurrarena.xlsx|Martin Vi...   Portugal    NaN
# 7   JonathanMurana_MartinViurrarena.xlsx|Martin Vi...    Francia    NaN
# 8   JonathanMurana_MartinViurrarena.xlsx|Martin Vi...  Argentina    NaN
# 11  JonathanMurana_MartinViurrarena.xlsx|Martin Vi...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    2.0  Uruguay-Portugal
# 5   Portugal    2.0  Uruguay-Portugal
# 7    Francia    3.0   Francia-Croacia
# 8    Croacia    1.0   Francia-Croacia
# 11    Brasil    2.0     Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Penca Argos Rusia 2018 AgustinPerez_6_AgustinP...    Uruguay    NaN
# 5   Penca Argos Rusia 2018 AgustinPerez_6_AgustinP...   Portugal    NaN
# 7   Penca Argos Rusia 2018 AgustinPerez_6_AgustinP...    Francia    NaN
# 8   Penca Argos Rusia 2018 AgustinPerez_6_AgustinP...  Argentina    NaN
# 11  Penca Argos Rusia 2018 AgustinPerez_6_AgustinP...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#       label  value            key1  \
# 4   Uruguay    2.0  Uruguay-España
# 5    España    1.0  Uruguay-España
# 7      Perú    2.0    Perú-Nigeria
# 8   Nigeria    0.0    Perú-Nigeria
# 11   Brasil    3.0   Brasil-México
#
#                                                    id      label  value  \
# 4   Javier Hernández_10_Gimena Norando.xlsx|Gimena...    Uruguay    NaN
# 5   Javier Hernández_10_Gimena Norando.xlsx|Gimena...   Portugal    NaN
# 7   Javier Hernández_10_Gimena Norando.xlsx|Gimena...    Francia    NaN
# 8   Javier Hernández_10_Gimena Norando.xlsx|Gimena...  Argentina    NaN
# ...
# 8   JonathanMurana_SebastianSilvera.xlsx|Sebastian...  Argentina    NaN
# 11  JonathanMurana_SebastianSilvera.xlsx|Sebastian...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    1.0  Uruguay-Portugal
# 5   Portugal    0.0  Uruguay-Portugal
# 7    Francia    2.0   Francia-Croacia
# 8    Croacia    0.0   Francia-Croacia
# 11    Brasil    3.0     Brasil-México
#
#                                                    id      label  value  \
# 4   SebastianAlvarez_3_MarioÁlvarez.xlsx|Mario Álv...    Uruguay    NaN
# 5   SebastianAlvarez_3_MarioÁlvarez.xlsx|Mario Álv...   Portugal    NaN
# 7   SebastianAlvarez_3_MarioÁlvarez.xlsx|Mario Álv...    Francia    NaN
# 8   SebastianAlvarez_3_MarioÁlvarez.xlsx|Mario Álv...  Argentina    NaN
# 11  SebastianAlvarez_3_MarioÁlvarez.xlsx|Mario Álv...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#         label  value               key1  \
# 4     Uruguay    2.0   Uruguay-Portugal
# 5    Portugal    1.0   Uruguay-Portugal
# 7     Francia    3.0  Francia-Argentina
# 8   Argentina    1.0  Francia-Argentina
# 11     Brasil    3.0      Brasil-Suecia
#
#                                                    id      label  value  \
# 4   MarianoMartinez_11_RaphaelHounie.xlsx|Raphael ...    Uruguay    NaN
# 5   MarianoMartinez_11_RaphaelHounie.xlsx|Raphael ...   Portugal    NaN
# 7   MarianoMartinez_11_RaphaelHounie.xlsx|Raphael ...    Francia    NaN
# 8   MarianoMartinez_11_RaphaelHounie.xlsx|Raphael ...  Argentina    NaN
# 11  MarianoMartinez_11_RaphaelHounie.xlsx|Raphael ...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    2.0  Uruguay-Portugal
# 5   Portugal    1.0  Uruguay-Portugal
# 7    Francia    2.0   Francia-Croacia
# 8    Croacia    0.0   Francia-Croacia
# 11    Brasil    3.0     Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Penca Argos Rusia 2018 AgustinPerez_5_Valentin...    Uruguay    NaN
# 5   Penca Argos Rusia 2018 AgustinPerez_5_Valentin...   Portugal    NaN
# 7   Penca Argos Rusia 2018 AgustinPerez_5_Valentin...    Francia    NaN
# 8   Penca Argos Rusia 2018 AgustinPerez_5_Valentin...  Argentina    NaN
# 11  Penca Argos Rusia 2018 AgustinPerez_5_Valentin...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#         label  value               key1  \
# 4     Uruguay    3.0   Uruguay-Portugal
# 5    Portugal    1.0   Uruguay-Portugal
# 7     Francia    1.0  Francia-Argentina
# 8   Argentina    2.0  Francia-Argentina
# 11     Brasil    3.0      Brasil-México
#
#                                                    id      label  value  \
# 4   NicolásFripp_21_GastónGuido.xlsx|Gastón Guido ...    Uruguay    NaN
# 5   NicolásFripp_21_GastónGuido.xlsx|Gastón Guido ...   Portugal    NaN
# 7   NicolásFripp_21_GastónGuido.xlsx|Gastón Guido ...    Francia    NaN
# 8   NicolásFripp_21_GastónGuido.xlsx|Gastón Guido ...  Argentina    NaN
# 11  NicolásFripp_21_GastónGuido.xlsx|Gastón Guido ...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    1.0  Uruguay-Portugal
# 5   Portugal    0.0  Uruguay-Portugal
# 7       Perú    1.0     Perú-Islandia
# 8   Islandia    0.0     Perú-Islandia
# 11    Brasil    2.0     Brasil-Suecia
#
#                                                    id      label  value  \
# 4   JonathanMurana_ShirleySilvera.xlsx|Shirley Sil...    Uruguay    NaN
# 5   JonathanMurana_ShirleySilvera.xlsx|Shirley Sil...   Portugal    NaN
# 7   JonathanMurana_ShirleySilvera.xlsx|Shirley Sil...    Francia    NaN
# 8   JonathanMurana_ShirleySilvera.xlsx|Shirley Sil...  Argentina    NaN
# 11  JonathanMurana_ShirleySilvera.xlsx|Shirley Sil...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#         label  value               key1  \
# 4     Uruguay    3.0   Uruguay-Portugal
# 5    Portugal    1.0   Uruguay-Portugal
# 7     Francia    2.0  Francia-Argentina
# 8   Argentina    1.0  Francia-Argentina
# 11     Brasil    4.0      Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Penca Argos Rusia 2018 - FedericoArmandPilon_1...    Uruguay    NaN
# 5   Penca Argos Rusia 2018 - FedericoArmandPilon_1...   Portugal    NaN
# 7   Penca Argos Rusia 2018 - FedericoArmandPilon_1...    Francia    NaN
# 8   Penca Argos Rusia 2018 - FedericoArmandPilon_1...  Argentina    NaN
# 11  Penca Argos Rusia 2018 - FedericoArmandPilon_1...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#         label  value                 key1  \
# 4     Uruguay    1.0       Uruguay-España
# 5      España    0.0       Uruguay-España
# 7   Dinamarca    0.0  Dinamarca-Argentina
# 8   Argentina    2.0  Dinamarca-Argentina
# 11     Brasil    2.0        Brasil-México
#
#                                                    id      label  value  \
# 4   Javier Hernández_26_Pablo Redes.xlsx|Pablo Red...    Uruguay    NaN
# 5   Javier Hernández_26_Pablo Redes.xlsx|Pablo Red...   Portugal    NaN
# 7   Javier Hernández_26_Pablo Redes.xlsx|Pablo Red...    Francia    NaN
# 8   Javier Hernández_26_Pablo Redes.xlsx|Pablo Red...  Argentina    NaN
# 11  Javier Hernández_26_Pablo Redes.xlsx|Pablo Red...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#         label  value               key1  \
# 4     Uruguay    3.0     Uruguay-España
# 5      España    2.0     Uruguay-España
# 7     Francia    2.0  Francia-Argentina
# 8   Argentina    0.0  Francia-Argentina
# 11     Brasil    3.0      Brasil-México
#
#                                                    id      label  value  \
# 4   LucasBouissa_6_PabloHernandez.xlsx|Pablo Herná...    Uruguay    NaN
# 5   LucasBouissa_6_PabloHernandez.xlsx|Pablo Herná...   Portugal    NaN
# 7   LucasBouissa_6_PabloHernandez.xlsx|Pablo Herná...    Francia    NaN
# 8   LucasBouissa_6_PabloHernandez.xlsx|Pablo Herná...  Argentina    NaN
# 11  LucasBouissa_6_PabloHernandez.xlsx|Pablo Herná...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    2.0  Uruguay-Portugal
# 5   Portugal    1.0  Uruguay-Portugal
# 7    Francia    3.0   Francia-Croacia
# 8    Croacia    1.0   Francia-Croacia
# 11    Brasil    3.0     Brasil-México
#
#                                                    id      label  value  \
# 4   Mauro_ 8 (MG).xlsx|Matias Guigou|matiasguigouj...    Uruguay    NaN
# 5   Mauro_ 8 (MG).xlsx|Matias Guigou|matiasguigouj...   Portugal    NaN
# 7   Mauro_ 8 (MG).xlsx|Matias Guigou|matiasguigouj...    Francia    NaN
# 8   Mauro_ 8 (MG).xlsx|Matias Guigou|matiasguigouj...  Argentina    NaN
# 11  Mauro_ 8 (MG).xlsx|Matias Guigou|matiasguigouj...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#       label  value             key1  \
# 4    Egipto    1.0    Egipto-España
# 5    España    2.0    Egipto-España
# 7   Francia    3.0  Francia-Nigeria
# 8   Nigeria    3.0  Francia-Nigeria
# 11   Brasil    2.0    Brasil-México
#
#                                                    id      label  value  \
# 4   Javier Hernández_3_Alvaro Arrillaga.xlsx|Alvar...    Uruguay    NaN
# 5   Javier Hernández_3_Alvaro Arrillaga.xlsx|Alvar...   Portugal    NaN
# 7   Javier Hernández_3_Alvaro Arrillaga.xlsx|Alvar...    Francia    NaN
# 8   Javier Hernández_3_Alvaro Arrillaga.xlsx|Alvar...  Argentina    NaN
# 11  Javier Hernández_3_Alvaro Arrillaga.xlsx|Alvar...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    2.0  Uruguay-Portugal
# 5   Portugal    1.0  Uruguay-Portugal
# 7    Francia    3.0   Francia-Croacia
# 8    Croacia    1.0   Francia-Croacia
# 11    Brasil    2.0     Brasil-Suecia
#
#                                                    id      label  value  \
# 4   Galvao_Penca Argos Rusia 2018_A-Menini_02 GALV...    Uruguay    NaN
# 5   Galvao_Penca Argos Rusia 2018_A-Menini_02 GALV...   Portugal    NaN
# 7   Galvao_Penca Argos Rusia 2018_A-Menini_02 GALV...    Francia    NaN
# 8   Galvao_Penca Argos Rusia 2018_A-Menini_02 GALV...  Argentina    NaN
# 11  Galvao_Penca Argos Rusia 2018_A-Menini_02 GALV...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    1.0  Uruguay-Portugal
# 5   Portugal    0.0  Uruguay-Portugal
# 7    Francia    2.0   Francia-Nigeria
# 8    Nigeria    0.0   Francia-Nigeria
# 11    Brasil    3.0     Brasil-México
#
#                                                    id      label  value  \
# 4   Penca Argos Rusia 2018 - FedericoArmandPilon_1...    Uruguay    NaN
# 5   Penca Argos Rusia 2018 - FedericoArmandPilon_1...   Portugal    NaN
# 7   Penca Argos Rusia 2018 - FedericoArmandPilon_1...    Francia    NaN
# 8   Penca Argos Rusia 2018 - FedericoArmandPilon_1...  Argentina    NaN
# 11  Penca Argos Rusia 2018 - FedericoArmandPilon_1...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value              key1  \
# 4    Uruguay    2.0  Uruguay-Portugal
# 5   Portugal    1.0  Uruguay-Portugal
# 7    Francia    3.0   Francia-Nigeria
# 8    Nigeria    1.0   Francia-Nigeria
# 11    Brasil    2.0     Brasil-México
#
#                                                    id      label  value  \
# 4   Javier Hernández_1_Agustin De León.xlsx|Agusti...    Uruguay    NaN
# 5   Javier Hernández_1_Agustin De León.xlsx|Agusti...   Portugal    NaN
# 7   Javier Hernández_1_Agustin De León.xlsx|Agusti...    Francia    NaN
# 8   Javier Hernández_1_Agustin De León.xlsx|Agusti...  Argentina    NaN
# 11  Javier Hernández_1_Agustin De León.xlsx|Agusti...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
#        label  value             key1  \
# 4     Egipto    0.0  Egipto-Portugal
# 5   Portugal    0.0  Egipto-Portugal
# 7    Francia    3.0  Francia-Croacia
# 8    Croacia    1.0  Francia-Croacia
# 11    Brasil    3.0    Brasil-México
#
#                                                    id      label  value  \
# 4   Javier Hernández_14_Jonnathan Silva.xlsx|Jonna...    Uruguay    NaN
# 5   Javier Hernández_14_Jonnathan Silva.xlsx|Jonna...   Portugal    NaN
# 7   Javier Hernández_14_Jonnathan Silva.xlsx|Jonna...    Francia    NaN
# 8   Javier Hernández_14_Jonnathan Silva.xlsx|Jonna...  Argentina    NaN
# 11  Javier Hernández_14_Jonnathan Silva.xlsx|Jonna...     Brasil    NaN
#
#                  key1                                         id
# 4    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 5    Uruguay-Portugal  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 7   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 8   Francia-Argentina  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
# 11      Brasil-México  RESULTADO_RESULTADO.xlsx|aaaaaa|q@asd.com
